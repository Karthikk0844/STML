# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statistics as stat
from scipy.stats import skew
from scipy.stats import kurtosis
from scipy.stats import iqr
data=pd.read_csv("/content/heartattack.csv",usecols=(['age']))
#data.tail(-1)
#print(data)
data=data['age']
p=data.head(1000)
print(data.head(1000))
#plt.hist(data,100)
print("The mean of the data=",np.mean(data))
print("The median of the data=",np.median(data))
print("The mode of the data=",stat.mode(data))
print("The SD of the data=",np.std(data))
print("The skew of the data=",skew(data,axis=0,bias=True))
print("The kurtosis of the data=",kurtosis(data,axis=0,bias=True))
print("The IQR of the data=",iqr(data))
import matplotlib.pyplot as plt
plt.hist(data, bins = 10) # replace 10 with the desired number of bins
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Age')
plt.show()
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64
# The mean of the data= 54.33993399339934
# The median of the data= 55.0
# The mode of the data= 58
# The SD of the data= 9.085582601944976
# The skew of the data= -0.1963585296364582
# The kurtosis of the data= -0.5696029537038148
# The IQR of the data= 14.0
